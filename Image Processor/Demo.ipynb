# %%
from auto_drive_functions import retrieve_angle
from ImageFrame import Frame
from PIL import Image
import numpy as np

# %%
frame1 = Frame(1280,720,10)
# Out:
# load CVS file successfully

# %%
import cv2
cam = cv2.VideoCapture(0)
img = cv2.cvtColor(cam.read()[1],cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-0e01dc639c86> in <module>
# ----> 1 import cv2
#       2 cam = cv2.VideoCapture(0)
#       3 img = cv2.cvtColor(cam.read()[1],cv2.COLOR_BGR2GRAY)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img = np.array(Image.open('1280x720_image.jpg'))[:,:,1]

# %%
data = frame1.get_data(img,5)

# %%
data
# Out:
# {'L1': array([[505., 666.,  53.],
#         [511., 665.,  47.],
#         [516., 664.,  40.],
#         [522., 663.,  35.],
#         [528., 662.,  37.],
#         [533., 661.,  38.],
#         [539., 660.,  38.],
#         [545., 659.,  40.],
#         [550., 658.,  43.],
#         [556., 657.,  48.],
#         [562., 656.,  53.],
#         [567., 655.,  57.],
#         [573., 654.,  62.],
#         [579., 653.,  67.],
#         [584., 652.,  67.],
#         [590., 651.,  66.],
#         [596., 650.,  64.],
#         [601., 649.,  61.],
#         [607., 648.,  59.],
#         [613., 647.,  60.],
#         [618., 646.,  61.],
#         [624., 645.,  57.],
#         [630., 644.,  54.],
#         [635., 643.,  55.],
#         [641., 642.,  59.],
#         [647., 641.,  63.],
#         [652., 640.,  67.],
#         [658., 639.,  68.],
#         [664., 638.,  65.],
#         [669., 637.,  63.],
#         [675., 636.,  60.],
#         [681., 635.,  55.],
#         [687., 634.,  52.],
# ...

# %%
angle = retrieve_angle(s1= 170,hd=5,img_path = img,frame = frame1,plot=True)

# %%
angle = retrieve_angle(s1= 20,hd=15,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([141.77565617,  91.24536427,  93.16388362, 105.0072654 ,
#         90.        ,  94.48460601,  92.03632545])

# %%
angle = retrieve_angle(s1= 30,hd=20,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([ 60.14098384, 101.5834186 , 113.26612971, 114.06964099,
#         88.36342296,  89.78047701,  92.03632545])

# %%
angle = retrieve_angle(s1= 40,hd=25,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([ 41.46770542, 128.4574399 ,  96.75357404, 113.21823254,
#        106.87937547,  88.39613723,  92.0373307 ])

# %%
angle = retrieve_angle(s1= 50,hd=30,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([ 90.53214364, 128.10257244, 101.1754987 , 107.14412017,
#        101.33561413,  89.56594937,  85.88269746])

# %%
angle = retrieve_angle(s1= 60,hd=35,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([90.53214364, 89.0122396 , 96.8842792 , 93.84817946, 88.38646107,
#        97.24656648, 85.9504183 ])

# %%
angle = retrieve_angle(s1= 70,hd=40,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([89.29615605, 85.54274993, 87.33183582, 89.60824009, 94.24845453,
#        86.77985725])

# %%
angle = retrieve_angle(s1= 60,hd=10,img_path='road1.jpg',frame = frame1,plot=True)
angle
# Out:
# array([ 90.53214364,  89.29615605, 101.01473435,  96.31343052,
#         89.61090052,  97.24656648,  85.50808422])
