# %%
from EdgeFinder import EdgeFinder as ef
import numpy as np

# %%
data = np.array([1,1,4,3,4,5,6,6,6,7,8,4,3,4,5,2,5,4,2,1,3,4,5,6,1,2,6,6,7,2,1,1,2,1,2,2,1,0,3,2,5,1,2,5,4,2])
line1 = ef(10,5,data)
print(line1.abnormal)
line1.plot_data()
# Out:
# {'up': [10.307495318350234, 9.684857057125711], 'low': [-1.7074953183502357, 1.1151429428742903], 'num': 19}
